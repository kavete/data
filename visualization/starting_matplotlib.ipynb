# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints= np.array([1,2,3,4,5])
ypoints= np.array([45, 34, 87, 65, 58])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### Level 3 title
# - Unordered list
#    - Item 1
#    - Item 2
#    - Item 3
#    - Item 4
# 1. Ordered list
# 2. Item 2

# %% [markdown]
# [Energy_management_app](https://etevak.pythonanywhere.com)
